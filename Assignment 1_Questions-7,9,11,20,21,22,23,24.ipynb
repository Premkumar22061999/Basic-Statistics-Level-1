# %% [markdown]
# #**Question 7_Basic Statistics_L 1**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
cars=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Assignment 1/Q7.csv')
cars
# Out:
#              Unnamed: 0  Points  Score  Weigh
# 0             Mazda RX4    3.90  2.620  16.46
# 1         Mazda RX4 Wag    3.90  2.875  17.02
# 2            Datsun 710    3.85  2.320  18.61
# 3        Hornet 4 Drive    3.08  3.215  19.44
# 4     Hornet Sportabout    3.15  3.440  17.02
# 5               Valiant    2.76  3.460  20.22
# 6            Duster 360    3.21  3.570  15.84
# 7             Merc 240D    3.69  3.190  20.00
# 8              Merc 230    3.92  3.150  22.90
# 9              Merc 280    3.92  3.440  18.30
# 10            Merc 280C    3.92  3.440  18.90
# 11           Merc 450SE    3.07  4.070  17.40
# 12           Merc 450SL    3.07  3.730  17.60
# 13          Merc 450SLC    3.07  3.780  18.00
# 14   Cadillac Fleetwood    2.93  5.250  17.98
# 15  Lincoln Continental    3.00  5.424  17.82
# 16    Chrysler Imperial    3.23  5.345  17.42
# 17             Fiat 128    4.08  2.200  19.47
# 18          Honda Civic    4.93  1.615  18.52
# ...

# %% [markdown]
# **Mean, Median, Mode**

# %%
cars.mean()
# Out:
# <ipython-input-16-9bac2de8474d>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cars.mean()
# Points     3.596563
# Score      3.217250
# Weigh     17.848750
# dtype: float64

# %%
cars.median()
# Out:
# <ipython-input-17-d6e4d6149093>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cars.median()
# Points     3.695
# Score      3.325
# Weigh     17.710
# dtype: float64

# %%
cars.Points.mode()
# Out:
# 0    3.07
# 1    3.92
# Name: Points, dtype: float64

# %%
cars.Score.mode()
# Out:
# 0    3.44
# Name: Score, dtype: float64

# %%
cars.Weigh.mode()
# Out:
# 0    17.02
# 1    18.90
# Name: Weigh, dtype: float64

# %%
cars.SP.mode()
# Out:
# 0    118.288996
# Name: SP, dtype: float64

# %% [markdown]
# **Variance, Standard Deviation & Range**

# %%
# Variance
cars.var()
# Out:
# <ipython-input-14-a4687f4bdf46>:2: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cars.var()
# Points    0.285881
# Score     0.957379
# Weigh     3.193166
# dtype: float64

# %%
# Satndard Deviation
cars.std()
# Out:
# <ipython-input-19-a84679174c1d>:2: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cars.std()
# Points    0.534679
# Score     0.978457
# Weigh     1.786943
# dtype: float64

# %%
# Range
cars.describe()
# Out:
#           Points      Score      Weigh
# count  32.000000  32.000000  32.000000
# mean    3.596563   3.217250  17.848750
# std     0.534679   0.978457   1.786943
# min     2.760000   1.513000  14.500000
# 25%     3.080000   2.581250  16.892500
# 50%     3.695000   3.325000  17.710000
# 75%     3.920000   3.610000  18.900000
# max     4.930000   5.424000  22.900000

# %%
Points_Range=cars.Points.max()-cars.Points.min()
Points_Range
# Out:
# 2.17

# %%
Score_Range=cars.Score.max()-cars.Score.min()
Score_Range
# Out:
# 3.9110000000000005

# %%
Weigh_Range=cars.Weigh.max()-cars.Weigh.min()
Weigh_Range
# Out:
# 8.399999999999999

# %% [markdown]
# **Data Visualization**

# %%
f,ax=plt.subplots(figsize=(15,5))
plt.subplot(1,3,1)
plt.boxplot(cars.Points)
plt.title('Points')
plt.subplot(1,3,2)
plt.boxplot(cars.Score)
plt.title('Score')
plt.subplot(1,3,3)
plt.boxplot(cars.Weigh)
plt.title('Weigh')
plt.show()
# Out:
# <ipython-input-25-563424e77c7f>:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,3,1)

# %% [markdown]
# #**Question 9(A)_Basic Statistics_L 1**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Assignment 1/Q9_a.csv')
data
# Out:
#     Index  speed  dist
# 0       1      4     2
# 1       2      4    10
# 2       3      7     4
# 3       4      7    22
# 4       5      8    16
# 5       6      9    10
# 6       7     10    18
# 7       8     10    26
# 8       9     10    34
# 9      10     11    17
# 10     11     11    28
# 11     12     12    14
# 12     13     12    20
# 13     14     12    24
# 14     15     12    28
# 15     16     13    26
# 16     17     13    34
# 17     18     13    34
# 18     19     13    46
# 19     20     14    26
# 20     21     14    36
# 21     22     14    60
# 22     23     14    80
# 23     24     15    20
# 24     25     15    26
# 25     26     15    54
# 26     27     16    32
# 27     28     16    40
# 28     29     17    32
# 29     30     17    40
# 30     31     17    50
# 31     32     18    42
# 32     33     18    56
# 33     34     18    76
# 34     35     18    84
# 35     36     19    36
# 36     37     19    46
# 37     38     19    68
# 38     39     20    32
# ...

# %% [markdown]
# **Skewness**

# %%
data.skew()
# Out:
# Index    0.000000
# speed   -0.117510
# dist     0.806895
# dtype: float64

# %% [markdown]
# **Kurtosis**

# %%
data.kurt()
# Out:
# Index   -1.200000
# speed   -0.508994
# dist     0.405053
# dtype: float64

# %% [markdown]
# #**Question 9(B)_Basic Statistics_L 1**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Assignment 1/Q9_b.csv')
data
# Out:
#     Unnamed: 0          SP         WT
# 0            1  104.185353  28.762059
# 1            2  105.461264  30.466833
# 2            3  105.461264  30.193597
# 3            4  113.461264  30.632114
# 4            5  104.461264  29.889149
# ..         ...         ...        ...
# 76          77  169.598513  16.132947
# 77          78  150.576579  37.923113
# 78          79  151.598513  15.769625
# 79          80  167.944460  39.423099
# 80          81  139.840817  34.948615
#
# [81 rows x 3 columns]

# %%
data2=data.iloc[:,1:]
data2
# Out:
#             SP         WT
# 0   104.185353  28.762059
# 1   105.461264  30.466833
# 2   105.461264  30.193597
# 3   113.461264  30.632114
# 4   104.461264  29.889149
# ..         ...        ...
# 76  169.598513  16.132947
# 77  150.576579  37.923113
# 78  151.598513  15.769625
# 79  167.944460  39.423099
# 80  139.840817  34.948615
#
# [81 rows x 2 columns]

# %% [markdown]
# **Skewness**

# %%
data2.skew()
# Out:
# SP    1.611450
# WT   -0.614753
# dtype: float64

# %% [markdown]
# Kurtosis

# %%
data2.kurt()
# Out:
# SP    2.977329
# WT    0.950291
# dtype: float64

# %% [markdown]
# #**Question 11_Basic Statistics_L 1**

# %%
import numpy as np
import pandas as pd
from scipy import stats
from scipy.stats import norm

# %% [markdown]
# **Avg. weight of Adult in Mexico with 94% CI**

# %%
stats.norm.interval(0.94,200,30/(2000**0.5))
# Out:
# (198.738325292158, 201.261674707842)

# %% [markdown]
# **Avg. weight of Adult in Mexico with 98% CI**

# %%
stats.norm.interval(0.98,200,30/(2000**0.5))
# Out:
# (198.43943840429978, 201.56056159570022)

# %% [markdown]
# **Avg. weight of Adult in Mexico with 96% CI**

# %%
stats.norm.interval(0.96,200,30/(2000**0.5))
# Out:
# (198.62230334813333, 201.37769665186667)

# %% [markdown]
# **For 96% confidence interval range is [198.62 – 201.37]**

# %% [markdown]
# #**Question 12_Basic Statistics_L 1**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
x=pd.Series([34,36,36,38,38,39,39,40,40,41,41,41,41,42,42,45,49,56])

# %% [markdown]
# **Mean, Median, Variance, Standard deviation**

# %%
# Mean
x.mean()
# Out:
# 41.0

# %%
# Median
x.median()
# Out:
# 40.5

# %%
# Variance
x.var()
# Out:
# 25.529411764705884

# %%
# Standard Deviation
x.std()
# Out:
# 5.05266382858645

# %% [markdown]
# **Data Visualization**

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f42f8dfc880>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f42f8dfcdc0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f42f8dfc5e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f42f8dfd300>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f42f8dfd5a0>],
#  'means': []}

# %% [markdown]
# **B) we don’t have outliers and the data is slightly skewed towards right because mean is greater than median**

# %% [markdown]
# #**Question 20_Basic Statistics_L 1**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import norm

# %%
cars=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Assignment 1/Cars.csv')
cars
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %% [markdown]
# **Data Visualization**

# %%
sns.boxplot(cars.MPG)
# Out:
# <Axes: >

# %% [markdown]
#  **P(MPG>38)**

# %%
stats.norm.cdf(38,cars.MPG.mean(),cars.MPG.std())
# Out:
# 0.6524060748417286

# %% [markdown]
# **P(MPG<40)**

# %%
stats.norm.cdf(40,cars.MPG.mean(),cars.MPG.std())
# Out:
# 0.7293498762151609

# %% [markdown]
# **P(20<MPG<50)**

# %%
stats.norm.cdf(0.50,cars.MPG.mean(),cars.MPG.std())-stats.norm.cdf(0.20,cars.MPG.mean(),cars.MPG.std())
# Out:
# 1.2430968797327491e-05

# %% [markdown]
# #**Question 21(A)_Basic Statistics_L 1**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
cars=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Assignment 1/Cars.csv')
cars
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %% [markdown]
# **Data Visualization**

# %%
sns.displot(cars.MPG, label='Cars-MPG')
plt.xlabel('MPG')
plt.ylabel('Density')
plt.legend();

# %% [markdown]
# **Normal Distribution**

# %%
cars.MPG.mean()
# Out:
# 34.42207572802469

# %%
cars.MPG.median()
# Out:
# 35.15272697

# %% [markdown]
# #**Question 21(B)_Basic Statistics_L 1**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Assignment 1/wc-at.csv')
data
# Out:
#       Waist      AT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# ..      ...     ...
# 104  100.10  124.00
# 105   93.30   62.20
# 106  101.80  133.00
# 107  107.90  208.00
# 108  108.50  208.00
#
# [109 rows x 2 columns]

# %% [markdown]
# **Data Visualization**

# %%
sns.displot(data.Waist)
plt.ylabel('density');

sns.displot(data.AT)
plt.ylabel('density');

# %% [markdown]
# **Mean & Median**

# %%
data.Waist.mean() , data.Waist.median()
# Out:
# (91.90183486238531, 90.8)

# %%
data.AT.mean() , data.AT.median()
# Out:
# (101.89403669724771, 96.54)

# %% [markdown]
# #**Question 22_Basic Statistics_L 1**

# %%
from scipy import stats
from scipy.stats import norm

# %% [markdown]
# **Z-score of 90% confidence interval**

# %%
stats.norm.ppf(0.95)
# Out:
# 1.6448536269514722

# %% [markdown]
# **Z-score of 94% confidence interval**

# %%
stats.norm.ppf(0.97)
# Out:
# 1.8807936081512509

# %% [markdown]
# **Z-score of 60% confidence interval**

# %%
stats.norm.ppf(0.8)
# Out:
# 0.8416212335729143

# %% [markdown]
# #**Question 23_Basic Statistics_L 1**

# %%
from scipy import stats
from scipy.stats import norm

# %% [markdown]
# **t scores of 95% confidence interval for sample size of 25**

# %%
stats.t.ppf(0.975,24)  # df = n-1 = 24
# Out:
# 2.0638985616280205

# %% [markdown]
# **t scores of 96% confidence interval for sample size of 25**

# %%
stats.t.ppf(0.98,24)
# Out:
# 2.1715446760080677

# %% [markdown]
# **t scores of 99% confidence interval for sample size of 25**

# %%
stats.t.ppf(0.995,24)
# Out:
# 2.796939504772804

# %% [markdown]
# #**Question 24_Basic Statistics_L 1**

# %%
from scipy import stats
from scipy.stats import norm

# %%
# Assume Null Hypothesis is: Ho = Avg life of Bulb >= 260 days
# Alternate Hypothesis is: Ha = Avg life of Bulb < 260 days

# %% [markdown]
# **find t-scores at x=260; t=(s_mean-P_mean)/(s_SD/sqrt(n))**

# %%
t=(260-270)/(90/18**0.5)
t
# Out:
# -0.4714045207910317

# %%
# Find P(X>=260) for null hypothesis

# %% [markdown]
# **p_value=1-stats.t.cdf(abs(t_scores),df=n-1)... Using cdf function**

# %%
p_value=1-stats.t.cdf(abs(-0.4714),df=17)
p_value
# Out:
# 0.32167411684460556

# %% [markdown]
# **OR p_value=stats.t.sf(abs(t_score),df=n-1)... Using sf function**

# %%
p_value=stats.t.sf(abs(-0.4714),df=17)
p_value
# Out:
# 0.32167411684460556
